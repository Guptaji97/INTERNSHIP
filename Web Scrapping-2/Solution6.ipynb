# %%
import selenium
from selenium import webdriver 
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
driver= webdriver.Chrome(r"C:\Users\amang\chromedriver_win32\chromedriver.exe")

# %%
url=" https://www.flipkart.com/"
driver.get(url)

# %%
#Terminate login pop up.
log=driver.find_element("xpath","/html/body/div[2]/div/div/button")
log.click()

# %%
# input in search bar
inp=driver.find_element("xpath","/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
inp.send_keys("Sneakers")

# %%
# Search
srch=driver.find_element("xpath","/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
srch.click()

# %%
#Getting brand details page 1
brand=[]
b=driver.find_elements("xpath",'//div[@class="_2WkVRV"]')

# %%
for i in b:
    a=len(brand)
    if a==100:
        break
    brand.append(i.text)
len(brand)
# Out:
# 40

# %%
#Getting description page 1
des=[]
d=driver.find_elements("xpath",'//a[@class="IRpwTa" or @class="IRpwTa _2-ICcC"]')

# %%
for i in d:
    a=len(des)
    if a==100:
        break
    des.append(i.text)
len(des)
# Out:
# 40

# %%
#Getting price details page 1
price=[]
p=driver.find_elements("xpath",'//div[@class="_30jeq3"]')

# %%
for i in p:
    a=len(price)
    if a==100:
        break
    price.append(i.text)
len(price)
# Out:
# 40

# %%
#getting  discount details 1
discount=[]
d=driver.find_elements("xpath",'//div[@class="_3Ay6Sb"]')

# %%
for i in d:
    a=len(discount)
    if a==100:
        break
    discount.append(i.text)
len(discount)
# Out:
# 40

# %%
nxt=driver.find_element("xpath","/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]")
nxt.click()

# %%
#Getting brand details page 2
b=driver.find_elements("xpath",'//div[@class="_2WkVRV"]')

# %%
for i in b:
    a=len(brand)
    if a==100:
        break
    brand.append(i.text)
len(brand)
# Out:
# 80

# %%
#Getting description page 2
d=driver.find_elements("xpath",'//a[@class="IRpwTa" or @class="IRpwTa _2-ICcC"]')

# %%
for i in d:
    a=len(des)
    if a==100:
        break
    des.append(i.text)
len(des)
# Out:
# 80

# %%
#Getting price details page 2
p=driver.find_elements("xpath",'//div[@class="_30jeq3"]')

# %%
for i in p:
    a=len(price)
    if a==100:
        break
    price.append(i.text)
len(price)
# Out:
# 80

# %%
#getting  discount details page 2
d=driver.find_elements("xpath",'//div[@class="_3Ay6Sb"]')

# %%
for i in d:
    a=len(discount)
    if a==100:
        break
    if i!=" ":
        discount.append(i.text)
    else:
        discount.append("0")
len(discount)
# Out:
# 80

# %%
nxt=driver.find_element("xpath","/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[12]")
nxt.click()

# %%
#Getting brand details page 3
b=driver.find_elements("xpath",'//div[@class="_2WkVRV"]')

# %%
for i in b:
    a=len(brand)
    if a==100:
        break
    brand.append(i.text)
len(brand)
# Out:
# 100

# %%
#Getting description page 3
d=driver.find_elements("xpath",'//a[@class="IRpwTa" or @class="IRpwTa _2-ICcC"]')

# %%
for i in d:
    a=len(des)
    if a==100:
        break
    des.append(i.text)
len(des)
# Out:
# 100

# %%
#Getting price details page 3
p=driver.find_elements("xpath",'//div[@class="_30jeq3"]')

# %%
for i in p:
    a=len(price)
    if a==100:
        break
    price.append(i.text)
len(price)
# Out:
# 100

# %%
#getting  discount details page 3
d=driver.find_elements("xpath",'//div[@class="_3Ay6Sb"]')

# %%
for i in d:
    a=len(discount)
    if a==100:
        break
    discount.append(i.text)
len(discount)
# Out:
# 100

# %%
df=pd.DataFrame({"Brand": brand, "Description":des, "Price":price, "Discount": discount})
df
# Out:
#             Brand                                        Description   Price  \
# 0            aadi                                   Sneakers For Men    ₹399
# 1        sixXplus  Sneakers For Men (Black) Casual For Men Sneake...    ₹521
# 2            PUMA           Smash v2 L White- Black Sneakers For Men  ₹2,029
# 3          BRUTON      Modern Trendy Sneakers Shoes Sneakers For Men    ₹269
# 4        URBANBOX                          Sneakers Sneakers For Men    ₹198
# ..            ...                                                ...     ...
# 95         Bonexy                                   Sneakers For Men    ₹474
# 96           PUMA                             Brave Sneakers For Men  ₹1,550
# 97       Roadster                                   Sneakers For Men  ₹1,135
# 98  WHITE WALKERS  Stylish & Trending Outdoor Walking Comfortable...    ₹599
# 99       WARMFEET                             Fancy Sneakers For Men    ₹649
#
#    Discount
# 0   80% off
# 1   47% off
# ...
