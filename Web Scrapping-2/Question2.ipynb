# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")

# %%
driver= webdriver.Chrome(r"C:\Users\amang\chromedriver_win32\chromedriver.exe")

# %%
url="http://www.naukri.com/"
driver.get(url)

# %%
# Input job postition
job= driver.find_element("xpath","/html/body/div[1]/div[2]/div[3]/div/div/div[1]/div/div/div/input")
job.send_keys("Data Scientist")

# %%
# Input Location
locn= driver.find_element("xpath","/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div/input")
locn.send_keys("Bangalore")

# %%
# Search button
srch= driver.find_element("xpath", "/html/body/div[1]/div[2]/div[3]/div/div/div[6]")
srch.click()

# %%
#Job Title
title=[]
tle= driver.find_elements("xpath", '//a[@class="title fw500 ellipsis"]')
len(tle)
# Out:
# 20

# %%
c=0
for i in tle:
    if c==10:
        break    
    title.append(i.text)
    c+=1
title
# Out:
# ['Urgent Job Opening For AI Practitioner - Data Science at Wipro Holmes',
#  'Opportunity For Data Scientist - Female Candidates ONLY',
#  'Research and Development -AI/ML -(PhD )',
#  'Data Scientist- Assistant Manager/Manager',
#  'Data Scientist: Artificial Intelligence',
#  'Senior Data Scientist, Personalization',
#  'Data Scientist',
#  'DigitalBCG GAMMA Data Scientist',
#  'Senior Data Science Engineer',
#  'Senior Data Scientist']

# %%
#Company name
company=[]
comp= driver.find_elements("xpath", '//a[@class="subTitle ellipsis fleft"]')
len(comp)
# Out:
# 20

# %%
c=0
for i in comp:
    if c==10:
        break
    c+=1
    company.append(i.text)
company
# Out:
# ['Wipro',
#  'PayU',
#  'EXL',
#  'Genpact',
#  'IBM',
#  'Walmart',
#  'Schneider Electric',
#  'Boston Consulting Group',
#  'Fractal Analytics',
#  'Baker Hughes']

# %%
# Experience
expr=[]
exp= driver.find_elements("xpath", '//li[@class="fleft grey-text br2 placeHolderLi experience"]')
len(exp)
# Out:
# 20

# %%
c=0
for i in exp:
    if c==10:
        break
    c+=1
    expr.append(i.text)
expr
# Out:
# ['11-21 Yrs',
#  '1-3 Yrs',
#  '4-8 Yrs',
#  '4-8 Yrs',
#  '3-7 Yrs',
#  '4-7 Yrs',
#  '6-9 Yrs',
#  '2-5 Yrs',
#  '5-9 Yrs',
#  '6-8 Yrs']

# %%
# TimeStamp
time=[]
t=driver.find_elements("xpath",'//div[@class="jobTupleFooter mt-20"]')
len(t)
# Out:
# 20

# %%
c=0
for i in t:
    if c==10:
        break
    c+=1
    a=i.text.split("\n")
    time.append(a[0])
time
# Out:
# ['1 DAY AGO',
#  '1 DAY AGO',
#  '13 DAYS AGO',
#  'JUST NOW',
#  'JUST NOW',
#  '1 DAY AGO',
#  '1 DAY AGO',
#  '1 DAY AGO',
#  '15 DAYS AGO',
#  '18 DAYS AGO']

# %%
df=pd.DataFrame({"Job Title": title, "Company": company, "Experience required": expr, "TimeStamp": time})
df
# Out:
#                                            Job Title                  Company  \
# 0  Urgent Job Opening For AI Practitioner - Data ...                    Wipro
# 1  Opportunity For Data Scientist - Female Candid...                     PayU
# 2            Research and Development -AI/ML -(PhD )                      EXL
# 3          Data Scientist- Assistant Manager/Manager                  Genpact
# 4            Data Scientist: Artificial Intelligence                      IBM
# 5             Senior Data Scientist, Personalization                  Walmart
# 6                                     Data Scientist       Schneider Electric
# 7                    DigitalBCG GAMMA Data Scientist  Boston Consulting Group
# 8                       Senior Data Science Engineer        Fractal Analytics
# 9                              Senior Data Scientist             Baker Hughes
#
#   Experience required    TimeStamp
# 0           11-21 Yrs    1 DAY AGO
# 1             1-3 Yrs    1 DAY AGO
# 2             4-8 Yrs  13 DAYS AGO
# 3             4-8 Yrs     JUST NOW
# 4             3-7 Yrs     JUST NOW
# 5             4-7 Yrs    1 DAY AGO
# 6             6-9 Yrs    1 DAY AGO
# 7             2-5 Yrs    1 DAY AGO
# 8             5-9 Yrs  15 DAYS AGO
# 9             6-8 Yrs  18 DAYS AGO
